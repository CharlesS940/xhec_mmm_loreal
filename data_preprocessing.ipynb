# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ap_variables = pd.read_csv("data/a&p_variables.csv")
commercial_variables = pd.read_csv("data/commercial_variables.csv")
kpi_variables = pd.read_csv("data/kpi_to_model.csv")

# %%
ap_variables
# Out:
#         growth_driver_l1     growth_driver_l2    growth_driver_l3  \
# 0     ap_consumer_facing  consumer_engagement      advocacy_media
# 1     ap_consumer_facing  consumer_engagement      advocacy_media
# 2     ap_consumer_facing  consumer_engagement      advocacy_media
# 3     ap_consumer_facing  consumer_engagement      advocacy_media
# 4     ap_consumer_facing  consumer_engagement      advocacy_media
# ...                  ...                  ...                 ...
# 2023  ap_consumer_facing   shopper_experience  shopper_experience
# 2024  ap_consumer_facing   shopper_experience  shopper_experience
# 2025  ap_consumer_facing   shopper_experience  shopper_experience
# 2026  ap_consumer_facing   shopper_experience  shopper_experience
# 2027  ap_consumer_facing   shopper_experience  shopper_experience
#
#                growth_driver_l4           growth_driver_l5       metric  \
# 0         influencer_management      influencer_management  engagements
# ...

# %%
commercial_variables
# Out:
#     Starting Week  Year  \
# 0      2022-01-03  2022
# 1      2022-01-10  2022
# 2      2022-01-17  2022
# 3      2022-01-24  2022
# 4      2022-01-31  2022
# ..            ...   ...
# 99     2023-11-27  2023
# 100    2023-12-04  2023
# 101    2023-12-11  2023
# 102    2023-12-18  2023
# 103    2023-12-25  2023
#
#      UK L'Oreal Paris Haircare Offline Average Price (in pound)  \
# 0                                             2.323822
# 1                                             2.328649
# 2                                             2.378280
# 3                                             2.396989
# 4                                             2.394615
# ..                                                 ...
# 99                                            3.067400
# 100                                           3.039699
# 101                                           3.057034
# 102                                           3.176955
# ...

# %%
kpi_variables
# Out:
#     Starting Week  Year  \
# 0      2022-01-03  2022
# 1      2022-01-10  2022
# 2      2022-01-17  2022
# 3      2022-01-24  2022
# 4      2022-01-31  2022
# ..            ...   ...
# 99     2023-11-27  2023
# 100    2023-12-04  2023
# 101    2023-12-11  2023
# 102    2023-12-18  2023
# 103    2023-12-25  2023
#
#      UK L'Oreal Paris Haircare Total Offline Sellout Value (in pound)  \
# 0                                            1583364.9
# 1                                            1753588.2
# 2                                            1690696.8
# 3                                            1748572.8
# 4                                            1768055.9
# ..                                                 ...
# 99                                           2472870.4
# 100                                          2464104.5
# 101                                          2686708.7
# 102                                          3397529.2
# ...

# %%
# Convert 'Starting Week' to datetime
ap_variables["Starting week"] = pd.to_datetime(ap_variables["Starting week"])
commercial_variables["Starting Week"] = pd.to_datetime(
    commercial_variables["Starting Week"]
)
kpi_variables["Starting Week"] = pd.to_datetime(kpi_variables["Starting Week"])

# rename column in ap_variables
ap_variables = ap_variables.rename(columns={"Starting week": "Starting Week"})

# %%
# Merge the datasets on 'Starting Week'
merged_data = pd.merge(
    ap_variables,
    commercial_variables,
    how="left",
    on="Starting Week",
)
merged_data = pd.merge(merged_data, kpi_variables, how="left", on="Starting Week")

# %%
merged_data
# Out:
#         growth_driver_l1     growth_driver_l2    growth_driver_l3  \
# 0     ap_consumer_facing  consumer_engagement      advocacy_media
# 1     ap_consumer_facing  consumer_engagement      advocacy_media
# 2     ap_consumer_facing  consumer_engagement      advocacy_media
# 3     ap_consumer_facing  consumer_engagement      advocacy_media
# 4     ap_consumer_facing  consumer_engagement      advocacy_media
# ...                  ...                  ...                 ...
# 2023  ap_consumer_facing   shopper_experience  shopper_experience
# 2024  ap_consumer_facing   shopper_experience  shopper_experience
# 2025  ap_consumer_facing   shopper_experience  shopper_experience
# 2026  ap_consumer_facing   shopper_experience  shopper_experience
# 2027  ap_consumer_facing   shopper_experience  shopper_experience
#
#                growth_driver_l4           growth_driver_l5       metric  \
# 0         influencer_management      influencer_management  engagements
# ...

# %%
# Check for missing values
missing_values = merged_data.isnull().sum()
missing_values
# Out:
# growth_driver_l1                                                        0
# growth_driver_l2                                                        0
# growth_driver_l3                                                        0
# growth_driver_l4                                                        0
# growth_driver_l5                                                        0
# metric                                                                  0
# Starting Week                                                           0
# investment (in pound)                                                   0
# execution                                                               0
# Year_x                                                                  0
# UK L'Oreal Paris Haircare Offline Average Price (in pound)              0
# UK L'Oreal Paris Haircare Online Average Price (in pound)               0
# UK L'Oreal Paris Haircare Total Weigheted Promotion Distribution (%)    0
# ...

# %%
merged_data["growth_driver_l1"].unique()
# Out:
# array(['ap_consumer_facing'], dtype=object)

# %%
merged_data["growth_driver_l2"].unique()
# Out:
# array(['consumer_engagement', 'shopper_experience'], dtype=object)

# %%
merged_data["growth_driver_l3"].unique()
# Out:
# array(['advocacy_media', 'paid_media', 'shopper_experience'], dtype=object)

# %%
merged_data["growth_driver_l4"].unique()
# Out:
# array(['influencer_management', 'digital_tv',
#        'online_multiformat_ads_transaction',
#        'online_video_content_platforms',
#        'paid_search_awarenessconsideration', 'paid_search_transaction',
#        'social_media_awarenessconsideration', 'social_media_transaction',
#        'traditional_tv', 'testers_and_merchandising'], dtype=object)

# %%
merged_data["growth_driver_l5"].unique()
# Out:
# array(['influencer_management', 'bvod', 'amazon_retail', 'tesco',
#        'google_video', 'youtube', 'google', 'amazon', 'citrus', 'criteo',
#        'meta', 'pinterest', 'tik_tok', 'meta_collab_ads', 'the_hut_group',
#        'linear', 'testers_and_merchandising'], dtype=object)

# %%
merged_data.to_csv("data/merged_data.csv", index=False)

# %%
merged_data.columns
# Out:
# Index(['growth_driver_l1', 'growth_driver_l2', 'growth_driver_l3',
#        'growth_driver_l4', 'growth_driver_l5', 'metric', 'Starting Week',
#        'investment (in pound)', 'execution', 'Year_x',
#        'UK L'Oreal Paris Haircare Offline Average Price (in pound)',
#        'UK L'Oreal Paris Haircare Online Average Price (in pound)',
#        'UK L'Oreal Paris Haircare Total Weigheted Promotion Distribution (%)',
#        'Year_y',
#        'UK L'Oreal Paris Haircare Total Offline Sellout Value (in pound)',
#        'UK L'Oreal Paris Haircare Total Offline Sellout Units',
#        'UK L'Oreal Paris Haircare Total Online Sellout Value (in pound)',
#        'UK L'Oreal Paris Haircare Total Online Sellout Units'],
#       dtype='object')

# %%
# Calculate total sales
merged_data['total_sales'] =merged_data['UK L\'Oreal Paris Haircare Total Offline Sellout Value (in pound)'] +merged_data['UK L\'Oreal Paris Haircare Total Online Sellout Value (in pound)']

# Create a new DataFrame to focus on sales by channel
sales_data =merged_data[['Year_x', 'UK L\'Oreal Paris Haircare Total Offline Sellout Value (in pound)', 
                 'UK L\'Oreal Paris Haircare Total Online Sellout Value (in pound)', 'total_sales']].copy()

# Plot
plt.figure(figsize=(10,6))
sales_data.set_index('Year_x')[['UK L\'Oreal Paris Haircare Total Offline Sellout Value (in pound)', 
                                'UK L\'Oreal Paris Haircare Total Online Sellout Value (in pound)']].plot(kind='bar', stacked=True)

plt.title('Sales by Channel (Offline vs Online)')
plt.ylabel('Sales in Pounds')
plt.xlabel('Year')
plt.xticks(rotation=45)
plt.legend(title='Sales Channel', labels=['Offline Sales', 'Online Sales'], loc='upper left')
plt.tight_layout()
plt.show()

# %%
kpi_variables
# Out:
#     Starting Week  Year  \
# 0      2022-01-03  2022
# 1      2022-01-10  2022
# 2      2022-01-17  2022
# 3      2022-01-24  2022
# 4      2022-01-31  2022
# ..            ...   ...
# 99     2023-11-27  2023
# 100    2023-12-04  2023
# 101    2023-12-11  2023
# 102    2023-12-18  2023
# 103    2023-12-25  2023
#
#      UK L'Oreal Paris Haircare Total Offline Sellout Value (in pound)  \
# 0                                            1583364.9
# 1                                            1753588.2
# 2                                            1690696.8
# 3                                            1748572.8
# 4                                            1768055.9
# ..                                                 ...
# 99                                           2472870.4
# 100                                          2464104.5
# 101                                          2686708.7
# 102                                          3397529.2
# ...

# %%
# Create the stacked area plot with light pink and dark pink colors
plt.figure(figsize=(12, 6))
plt.stackplot(kpi_variables['Starting Week'], 
              kpi_variables['Offline Sales'], 
              kpi_variables['Online Sales'], 
              labels=['Offline Sales', 'Online Sales'],
              colors=['#FFB6C1', '#FF69B4'])  # Light pink and dark pink

# Add labels, title, and legend
plt.title('Weekly Sales by Channel (Offline vs Online)', fontsize=16)
plt.xlabel('Week', fontsize=12)
plt.ylabel('Sales (in pounds)', fontsize=12)
plt.legend(loc='upper left', fontsize=12)

# Format x-axis to show dates neatly
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.grid(True, linestyle='--', alpha=0.6)  # Add gridlines for clarity

# Show the plot
plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()
