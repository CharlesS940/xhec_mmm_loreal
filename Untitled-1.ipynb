# %%
import pandas as pd

# %%
data = {
    'Category': [
    'digital_tv',
    'influencer_management',
    'online_multiformat_ads_transaction',
    'online_video_content_platforms',
    'paid_search_awarenessconsideration',
    'paid_search_transaction',
    'social_media_awarenessconsideration',
    'social_media_transaction',
    'traditional_tv'
],
    'Incremental Revenue CY2022': [823, 458, 11096, 1896, 6, 9693, 5348, 8611, 39797],
    'Incremental Revenue CY2023': [939, 291, 11478, 1748, 10, 9953, 4636, 8645, 38156],
        'Spend CY2022': [
        6555,  # digital_tv
        9060,  # influencer_management
        4752,  # online_multiformat_ads_transaction
        15890, # online_video_content_platforms
        1050,  # paid_search_awarenessconsideration
        15770, # paid_search_transaction
        25610, # social_media_awarenessconsideration
        6780,  # social_media_transaction
        94730  # traditional_tv
    ],
    'Spend CY2023': [
        10490, # digital_tv
        8460,  # influencer_management
        16795, # online_multiformat_ads_transaction
        15270, # online_video_content_platforms
        1890,  # paid_search_awarenessconsideration
        22260, # paid_search_transaction
        22210, # social_media_awarenessconsideration
        8740,  # social_media_transaction
        100630 # traditional_tv
    ],
    'ROI CY2022': [0.34, 0.13, 2.34, 0.31, 0.02, 1.58, 0.55, 3.3, 1.09],
    'ROI CY2023': [0.28, 0.09, 2.11, 0.34, 0.03, 1.40, 0.65, 3.88, 1.18]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                               Category  Incremental Revenue CY2022  \
# 0                           digital_tv                         823
# 1                influencer_management                         458
# 2   online_multiformat_ads_transaction                       11096
# 3       online_video_content_platforms                        1896
# 4   paid_search_awarenessconsideration                           6
# 5              paid_search_transaction                        9693
# 6  social_media_awarenessconsideration                        5348
# 7             social_media_transaction                        8611
# 8                       traditional_tv                       39797
#
#    Incremental Revenue CY2023  Spend CY2022  Spend CY2023  ROI CY2022  \
# 0                         939          6555         10490        0.34
# 1                         291          9060          8460        0.13
# 2                       11478          4752         16795        2.34
# 3                        1748         15890         15270        0.31
# 4                          10          1050          1890        0.02
# 5                        9953         15770         22260        1.58
# 6                        4636         25610         22210        0.55
# 7                        8645          6780          8740        3.30
# 8                       38156         94730        100630        1.09
#
#    ROI CY2023
# 0        0.28
# 1        0.09
# 2        2.11
# 3        0.34
# 4        0.03
# 5        1.40
# 6        0.65
# 7        3.88
# 8        1.18

# %%
df['contribution 2022'] = df['Incremental Revenue CY2022']/ 755126

# %%
df
# Out:
#                               Category  Incremental Revenue CY2022  \
# 0                           digital_tv                         823
# 1                influencer_management                         458
# 2   online_multiformat_ads_transaction                       11096
# 3       online_video_content_platforms                        1896
# 4   paid_search_awarenessconsideration                           6
# 5              paid_search_transaction                        9693
# 6  social_media_awarenessconsideration                        5348
# 7             social_media_transaction                        8611
# 8                       traditional_tv                       39797
#
#    Incremental Revenue CY2023  Spend CY2022  Spend CY2023  ROI CY2022  \
# 0                         939          6555         10490        0.34
# 1                         291          9060          8460        0.13
# 2                       11478          4752         16795        2.34
# 3                        1748         15890         15270        0.31
# 4                          10          1050          1890        0.02
# 5                        9953         15770         22260        1.58
# 6                        4636         25610         22210        0.55
# 7                        8645          6780          8740        3.30
# 8                       38156         94730        100630        1.09
#
#    ROI CY2023  contribution 2022
# 0        0.28           0.001090
# 1        0.09           0.000607
# 2        2.11           0.014694
# 3        0.34           0.002511
# 4        0.03           0.000008
# 5        1.40           0.012836
# 6        0.65           0.007082
# 7        3.88           0.011403
# 8        1.18           0.052702

# %%
df['contribution 2023'] = df['Incremental Revenue CY2023']/ 808079

# %%
df
# Out:
#                               Category  Incremental Revenue CY2022  \
# 0                           digital_tv                         823
# 1                influencer_management                         458
# 2   online_multiformat_ads_transaction                       11096
# 3       online_video_content_platforms                        1896
# 4   paid_search_awarenessconsideration                           6
# 5              paid_search_transaction                        9693
# 6  social_media_awarenessconsideration                        5348
# 7             social_media_transaction                        8611
# 8                       traditional_tv                       39797
#
#    Incremental Revenue CY2023  Spend CY2022  Spend CY2023  ROI CY2022  \
# 0                         939          6555         10490        0.34
# 1                         291          9060          8460        0.13
# 2                       11478          4752         16795        2.34
# 3                        1748         15890         15270        0.31
# 4                          10          1050          1890        0.02
# 5                        9953         15770         22260        1.58
# 6                        4636         25610         22210        0.55
# 7                        8645          6780          8740        3.30
# 8                       38156         94730        100630        1.09
#
#    ROI CY2023  contribution 2022  contribution 2023
# 0        0.28           0.001090           0.001162
# 1        0.09           0.000607           0.000360
# 2        2.11           0.014694           0.014204
# 3        0.34           0.002511           0.002163
# 4        0.03           0.000008           0.000012
# 5        1.40           0.012836           0.012317
# 6        0.65           0.007082           0.005737
# 7        3.88           0.011403           0.010698
# 8        1.18           0.052702           0.047218

# %%
13.9/31
# Out:
# 0.4483870967741936

# %%
13.2/31
# Out:
# 0.4258064516129032
